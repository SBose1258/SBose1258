# %% [markdown]
# Connecting Google Collab to Tableau Desktop

# %%
pip install openai==0.28

# %%
import openai
import pandas as pd
import numpy as np

# %%
openai.api_key='sk-wnlaoUqnzm65fUuErGeX0bG-GczK_5XQY1bACJ5SbtT3BlbkFJHw_53gBd2p_qMNLqNXTto2IcopPF4oFVuiIx-zAnoA'

# %%
path="/content/drive/MyDrive/Prompt_Project_Datasets/diabetes.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Convert the data to a format the OpenAI API can understand.
